# %%
import matplotlib
import warnings
warnings.filterwarnings('ignore')  # 차트를 그리다보면 warning 메세지들이 겹쳐서 나오기도 해서

# %%
import matplotlib.font_manager as fm
for i in fm.fontManager.ttflist:
    if i.name.find('Gothic') != -1 : #Gulim,Gothic
        print(i.name)
# Out:
# Franklin Gothic Medium
# Franklin Gothic Medium
# Malgun Gothic
# Franklin Gothic Demi Cond
# Yu Gothic
# HYGothic-Extra
# Century Gothic
# Copperplate Gothic Bold
# Franklin Gothic Book
# Malgun Gothic
# Hancom Gothic
# Yu Gothic
# Franklin Gothic Book
# MS Gothic
# Century Gothic
# Malgun Gothic
# Hancom Gothic
# Franklin Gothic Heavy
# HYGothic-Medium
# Franklin Gothic Medium Cond
# Copperplate Gothic Light
# Franklin Gothic Demi
# Franklin Gothic Demi
# Franklin Gothic Heavy
# Showcard Gothic
# Yu Gothic
# Century Gothic
# Yu Gothic
# Century Gothic

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Malgun Gothic' #matplotlib에 사용할 기본 폰트 지정
rcParams['axes.unicode_minus'] = False  # 차트에서 마이너스가 깨질때 해주는 설정

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)
plt.title('사인 곡선')
plt.xlabel('시간')
plt.ylabel('진폭')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 1. 데이터 시각화의 중요성

# %% [markdown]
# ![6741511B-DC97-4A8D-86D3-6FB6AA9C02C1.png](attachment:aefdb82c-2aaf-451c-a8ca-2ee0a72ff300.png)
#
# 요약통계가 모두 똑같은 4개의 데이터셋, but 시각화 했을 때 전혀 다른 차트를 보여줌

# %%
import seaborn as sns
import pandas as pd
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %% [markdown]
# # 2. Matplotlib 라이브러리

# %%
import matplotlib.pyplot as plt
#plt.plot()

# %%
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']
d1.shape,d2.shape,d3.shape,d4.shape
# Out:
# ((11, 3), (11, 3), (11, 3), (11, 3))

# %%
# 2개의 요소 x,y 가짐
plt.plot(d1['x'],d1.y, 'o')
plt.show() # show를 안해도 되긴 하지만 해주는게 낫다

# %%
plt.plot(d2['x'],d2.y)
plt.show()

# %% [markdown]
# ![BD137B35-C855-47F2-8754-F403A15B8CB6.png](attachment:b8e05d3d-2ef1-4aeb-bfa9-2ae85b0f3605.png)

# %%
# 차트를 한 영역안에 비교할 수 있도록 모아놓는 기능 = subplot()
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1) #2행, 2열, 포지션
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)
plt.show()

# %%
fig = plt.figure() #주피터 노트북에서는 그림 그리는 공간을 지나면 사라진다 그래서 같은 곳에서 실행시켜야함 
axes1 = fig.add_subplot(2,2,1) #2행, 2열, 포지션
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)
axes1.plot(d1['x'],d1.y, 'o')
axes2.plot(d2['x'],d2.y, 'o')
axes3.plot(d3['x'],d3.y, 'o')
axes4.plot(d4['x'],d4.y, 'o')

fig.suptitle('Anscombe Dataset으로 보는 데이터 시각화의 의미')
axes1.set_title('dataset 1')
axes2.set_title('dataset 2')
axes3.set_title('dataset 3')
axes4.set_title('dataset 4')

fig.set_tight_layout(True)  #차트끼리 겹쳐지지 않게 하기 위해서

plt.show()

# %% [markdown]
# 데이터를 요약한 통계만으로 판단하는 것은 완전하지 않다.
# 시각화를 통해 경향을 파악하는 것이 중요하다.

# %%
# 새로운 데이터셋 로드
# tips 데이터셋, 팁, 청구서전체금액, 일행수, 요일, 시간, 흡연여부, 성별
tips = sns.load_dataset('tips')
tips.head(), tips.shape
# Out:
# (   total_bill   tip     sex smoker  day    time  size
#  0       16.99  1.01  Female     No  Sun  Dinner     2
#  1       10.34  1.66    Male     No  Sun  Dinner     3
#  2       21.01  3.50    Male     No  Sun  Dinner     3
#  3       23.68  3.31    Male     No  Sun  Dinner     2
#  4       24.59  3.61  Female     No  Sun  Dinner     4,
#  (244, 7))

# %% [markdown]
# ## 1. 일변량 그래프
#
# 변수 하나를 갖고 그리는 그래프
#
# - 히스토그램 : 구간의 *빈도 수*를 시각화하는 그래프, x의 구간을 나누어 y는 빈도 수
#   - 연속형 데이터에 알맞음

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.hist(data= tips, x='total_bill', bins=20)  #bin=막대의 수
plt.show()
# 연속형 수치여만 히스토그램에서 의미가 있다

# %%
# 막대그래프 - 범주형 데이터에 알맞음
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
sns.countplot(data= tips, x='day') 
plt.show()

# %%
# 상자그림(박스 플랏) - 연속형 변수의 분포를 나타내는 그래프
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.boxplot(data= tips, x='total_bill') 
plt.show()

# %% [markdown]
# ## 2. 이변량 그래프
#
# 시각화하고자 하는 변수가 2개일 때

# %% [markdown]
# ### 1. 산점도(scatter plot)

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.scatter(tips['total_bill'], tips['tip']) # 총 지불 금액과 팁의 관계
plt.show()

# %% [markdown]
# ### 2. 상자그림 (box plot)

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.boxplot(
    x=[tips[tips['sex']=='Female']['tip'],
       tips[tips['sex']=='Male']['tip']],
labels=['Female','Male']) # 총 지불 금액과 팁의 관계
plt.show()

# %% [markdown]
# ## 3. 다변량 그래프

# %%
#map()함수에 사용
colors = {"Female": "#f1a340", "Male": "#998ec3"} # 성별에 따른 색상을 지정, 여성은 주황색, 남성은 보라색 
#16진수 코드는 https://www.w3schools.com/colors/colors_picker.asp 에서 확인 가능

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(data=tips,
              x='total_bill',
              y='tip',
              s=tips['size']**2*10,# size를 제곱하여 점의 크기를 키움, s는 점의 크기를 나타내는 매개변수
              c=tips['sex'].map(colors),# map()은 Series의 각 요소에 대해 특정 함수를 적용할 때 사용, c는 점의 색을 나타내는 매개변수, colors 딕셔너리에 따라 여성은 주황색, 남성은 보라색
              alpha=0.5) # alpha는 점의 투명도를 나타내는 매개변수

axes1.set_title('Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

scatter_plot.suptitle('Total Bill vs Tip')

plt.show()

# %% [markdown]
# # 3. Seaborn 라이브러리

# %% [markdown]
# ## 1. 일변량 그래프

# %%
sns.histplot(data=tips,x='total_bill')
plt.show()

# %%
sns.kdeplot(data=tips, x='total_bill')
plt.show()

# %%
sns.rugplot(data=tips,x='total_bill')
sns.histplot(data=tips,x='total_bill')
plt.show()

# %%
cnt, ax = plt.subplots()
sns.countplot(data=tips,x='day',palette='viridis')
ax.set_title('요일별 건수')
plt.show()

# %% [markdown]
# ### 2. 이변량 그래프

# %%
cnt, ax = plt.subplots()
sns.scatterplot(data=tips,x='total_bill',y='tip', ax=ax, hue='sex', palette='viridis')
ax.set_title('지불금액과 팁의 관계')
plt.show()

# %%
cnt, ax = plt.subplots()
sns.regplot(data=tips,x='total_bill',y='tip', ax=ax)
ax.set_title('지불금액과 팁의 관계')
plt.show()

# %%
#joint plot - 알아서 그림들을 만들어서 차트를 합쳐준다
joint = sns.jointplot(data=tips,x='total_bill',y='tip')
joint.set_axis_labels(xlabel='TotalBill',ylabel='Tip')
joint.figure.suptitle('TotalBill과 Tips의 조인트차트')
plt.show()

# %%
kde, ax = plt.subplots()
sns.kdeplot(data=tips, x='total_bill', y='tip', fill=True, ax=ax)
ax.set_title('KDE Plot')
plt.show()

# %%
# bar plot
bar, ax = plt.subplots()
sns.barplot(data=tips, x='time', y='total_bill', estimator=np.mean, ax=ax)
ax.set_title('Bar Plot')
plt.show()

# %%
# box plot
box, ax = plt.subplots()
sns.boxplot(data=tips, x='time', y='total_bill', ax=ax)
ax.set_title('Box Plot')
plt.show()

# %%
#violin plot  - 히스토그램과 박스플랏을 합친 차트
box, ax = plt.subplots()
sns.violinplot(data=tips, x='time', y='total_bill', ax=ax)
ax.set_title('Violin Plot')
plt.show()

# %% [markdown]
# ### 3. pairplot

# %%
fig = sns.pairplot(data=tips)
fig.figure.suptitle('Tips 데이터의 관계분석')
plt.show()

# %% [markdown]
# https://matplotlib.org/cheatsheets/_images/cheatsheets-1.png

# %% [markdown]
# ![66EE8394-47AF-4EBC-8BFB-9040B04D488D.png](attachment:a526a08e-996c-475f-a9bf-f1de044472a1.png)
